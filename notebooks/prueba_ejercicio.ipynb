# %%
print("Hola, mundo")
# Out:
# Hola, mundo

# %%
import sys
sys.path.append("../src")

# %%
import cifrado_cesar
# Out:
# Traceback (most recent call last):
#
#   File ~\Documents\Ciencia de Datos\2026\Taller de lenguajes\lenguajes_practica2\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3747 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[5], line 1
#     import cifrado_cesar
#
#   File ~\Documents\Ciencia de Datos\2026\Taller de lenguajes\lenguajes_practica2\notebooks\../src\cifrado_cesar.py:6
#     start = ord("A") if char.isupper()
#             ^
# SyntaxError: expected 'else' after 'if' expression

# %%
import cifrado_cesar
